# %%
from src.data_analysis.dataset_viewer import look_into_datasets
# Out:
# Package for analysis the embeddings/cls token of the peptide sequences from the fine-tuned model.
# !!!STILL IN WORK AND NOT FULLY TESTED!!!

# %%
list_of_datasets = [
    # ("../../data/train_data/our_hemo_labeled.csv", ";"),
    # ("../../data/train_data/our_hemo_labeled_filtered.csv", ";"),
    # ("../../data/train_data/test_filtered.csv", ";"),
    # ("../../data/train_data/train_test_data.csv", ";"),
    ("../../data/train_data/happen_style_unvoted.csv", ";"),
    ("../../data/train_data/happen_style_filtered_unvoted.csv", ";")
    # Add more datasets as needed
 ]
file_for_k_mer_analysis = [
    ("../../data/data_for_data_viewer/happen_style_high_difference_sequences_50.csv", ";"),
    ("../../data/data_for_data_viewer/happen_style_high_difference_sequences_100.csv", ";")
]

# %%
look_into_datasets(file_paths=list_of_datasets,
                   k_mer_inspection_file=file_for_k_mer_analysis,
                   show_top_kmers=100)
# Out:
# Generating Info for ../../data/train_data/happen_style_unvoted.csv:
# Number of sequences: 6636
# Number of unique sequences: 4209
# Correlation between sequence length and label: 0.124
# Generating Info for ../../data/train_data/happen_style_filtered_unvoted.csv:
# Number of sequences: 4471
# Number of unique sequences: 3589
# Correlation between sequence length and label: 0.121
# Generating Info for ../../data/data_for_data_viewer/happen_style_high_difference_sequences_50.csv:
# Number of sequences: 2165
# Differences in hemolytic concentrations inside one sequence
# [WARNING]Extrem Values are set to 0! Its expected that data feeded here only show data OVER a certrain threshold set by train_data creation!!!
# (2165, 5)
# Check for k_mer content
# [('KIA', 504), ('FKK', 480), ('KKL', 461), ('KKI', 454), ('AKK', 398), ('LLK', 347), ('KLF', 338), ('LFK', 336), ('KKF', 320), ('KKK', 283), ('LKK', 280), ('ILK', 278), ('KIL', 277), ('AGK', 276), ('IAG', 269), ('GKI', 259), ('KLL', 250), ('LKL', 221), ('IAK', 221), ('LKY', 220), ('KYL', 202), ('KFL', 192), ('AAA', 186), ('KAA', 172), ('KLK', 172), ('AKI', 172), ('AAF', 161), ('GIG', 148), ('FLH', 147), ('AFA', 145), ('KKA', 144), ('KWL', 143), ('FAA', 138), ('KWK', 134), ('LKW', 130), ('IKK', 128), ('KFK', 122), ('KAF', 117), ('LAK', 116), ('GKA', 114), ('IGK', 107), ('AAK', 106), ('FLP', 100), ('KAL', 99), ('LKF', 99), ('AAL', 96), ('LAG', 93), ('FAK', 88), ('KFA', 88), ('KAI', 86), ('AFK', 86), ('LGK', 85), ('VLK', 85), ('KRL', 84), ('KKV', 83), ('GAV', 82), ('KVL', 82), ('KSL', 82), ('IGA', 81), ('WKL', 81), ('SAK', 81), ('LKA', 80), ('GGL', 80), ('IIK', 79), ('LHS', 78), ('HSA', 78), ('ALA', 77), ('VGK', 76), ('AIA', 76), ('AVL', 75), ('WLL', 74), ('RRR', 74), ('GKF', 74), ('FGK', 74), ('KIK', 73), ('LIS', 71), ('LHL', 71), ('YLA', 70), ('VLT', 68), ('GLI', 68), ('FKA', 68), ('CKI', 67), ('IPK', 66), ('HVG', 65), ('FKR', 64), ('LPA', 64), ('AAW', 64), ('WAA', 64), ('AGP', 64), ('GPA', 64), ('HLA', 63), ('IAA', 63), ('KVF', 62), ('GLL', 62), ('WIK', 60), ('KIP', 60), ('AWA', 60), ('WLK', 58), ('AIK', 58), ('KKW', 57)]
# Generating Info for ../../data/data_for_data_viewer/happen_style_high_difference_sequences_100.csv:
# Number of sequences: 1410
# Differences in hemolytic concentrations inside one sequence
# [WARNING]Extrem Values are set to 0! Its expected that data feeded here only show data OVER a certrain threshold set by train_data creation!!!
# (1410, 5)
# Check for k_mer content
# [('KIA', 483), ('KKL', 321), ('KKI', 305), ('KKK', 254), ('FKK', 252), ('IAG', 251), ('AGK', 249), ('GKI', 243), ('LLK', 235), ('KLF', 232), ('ILK', 223), ('KIL', 217), ('IAK', 211), ('LFK', 205), ('AKK', 198), ('LKY', 195), ('KYL', 183), ('AAA', 181), ('KLL', 172), ('AKI', 166), ('AAF', 153), ('LKL', 152), ('LKK', 143), ('AFA', 143), ('FAA', 138), ('KWL', 112), ('KFL', 100), ('LKW', 98), ('KAA', 97), ('KKF', 97), ('IKK', 97), ('KLK', 96), ('KKA', 94), ('LAG', 87), ('AAK', 84), ('GIG', 82), ('IGK', 78), ('IIK', 77), ('GKA', 74), ('AIA', 70), ('AAL', 69), ('KAF', 69), ('LKA', 68), ('FLH', 68), ('KIK', 67), ('KAL', 66), ('LKF', 65), ('WLL', 64), ('KWK', 64), ('LPA', 64), ('AAW', 64), ('WAA', 64), ('FGK', 64), ('YLA', 63), ('RRR', 62), ('GKF', 62), ('HSA', 62), ('SAK', 62), ('AGP', 62), ('GPA', 62), ('IAA', 61), ('AWA', 60), ('LHS', 60), ('KAI', 59), ('WIK', 58), ('IKI', 56), ('RCK', 53), ('KSL', 52), ('VLK', 51), ('LIS', 50), ('GGL', 47), ('ALG', 47), ('YLK', 47), ('LGK', 46), ('TGL', 46), ('KVL', 45), ('PAL', 45), ('WLK', 44), ('ALI', 44), ('LAK', 43), ('KFG', 43), ('GLP', 42), ('AFV', 42), ('GLF', 42), ('KDE', 42), ('DEL', 42), ('WRR', 41), ('GAV', 41), ('TTG', 41), ('ISW', 40), ('LGA', 39), ('FLP', 39), ('KKW', 38), ('WKW', 38), ('WPW', 38), ('IGA', 38), ('RKR', 38), ('KII', 38), ('EIM', 38), ('MNS', 37)]
