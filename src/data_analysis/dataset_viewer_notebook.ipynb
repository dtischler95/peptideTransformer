# %%
from src.data_analysis.dataset_viewer import look_into_datasets
# Out:
# Package for analysis the embeddings/cls token of the peptide sequences from the fine-tuned model.
# !!!STILL IN WORK AND NOT FULLY TESTED!!!

# %%
list_of_datasets = [
    # ("../../data/train_data/our_hemo_labeled.csv", ";"),
    # ("../../data/train_data/our_hemo_labeled_filtered.csv", ";"),
    # ("../../data/train_data/test_filtered.csv", ";"),
    # ("../../data/train_data/train_test_data.csv", ";"),
    ("../../data/train_data/whitelab_hemo_data.csv", ';'),
    ("../../data/train_data/happen_style_unvoted.csv", ";"), # Contains all Data
    #("../../data/train_data/happen_style_filtered_50_unvoted.csv", ";"), # removed data with concentration dif more than 50
    #("../../data/train_data/happen_style_filtered_100_unvoted.csv", ";") #  removed data with concentration dif more than 100
    # Add more datasets as needed
 ]
# Analysis for data currently removed from train data set
file_for_k_mer_analysis = [
    ("../../data/data_for_data_viewer/happen_style_high_difference_sequences_50.csv", ";"),
    ("../../data/data_for_data_viewer/happen_style_high_difference_sequences_100.csv", ";")
]

# %%
look_into_datasets(file_paths=list_of_datasets,
                   k_mer_inspection_file=file_for_k_mer_analysis,
                   show_top_kmers=100,
                   out_path='../../final_plots/')
# Out:
# ----------------------------Analysing Train Files-------------------------------------
# -----------------Generating Info for ../../data/train_data/whitelab_hemo_data.csv:----------------------------------------
#
#
# Number of sequences: 9316
# Number of unique sequences: 6076
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/regressor/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hemo_concentration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 look_into_datasets(file_paths=list_of_datasets,
#       2                    k_mer_inspection_file=file_for_k_mer_analysis,
#       3                    show_top_kmers=100,
#       4                    out_path='../../final_plots/')
#
# File ~/Projects/peptideTransformer/src/data_analysis/dataset_viewer.py:42, in look_into_datasets(file_paths, k_mer_inspection_file, show_top_kmers, out_path)
#      39 print(f"\033Number of unique sequences: {df['sequence'].nunique()}\n\033")
#      41 plot_binary_label_distribution(df, plot_path=out_path)
# ---> 42 plot_concentration_to_percent(df, plot_path=out_path)
#      43 sequences_0 = df[df["label"] == 0]["sequence"].tolist()
#      44 sequences_1 = df[df["label"] == 1]["sequence"].tolist()
#
# File ~/Projects/peptideTransformer/src/data_analysis/dataset_viewer.py:384, in plot_concentration_to_percent(df, plot_path)
#     380 """
#     381 Plot the concentration to percent ratio.
#     382 """
#     383 # sort values by concentration for cleaner curve
# --> 384 df = df[df['hemo_concentration'] < 500]
#     385 df = df.sort_values(by='hemo_percent', ascending=False).reset_index(drop=True)
#     388 data_index = df.index
#
# File ~/miniconda3/envs/regressor/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/miniconda3/envs/regressor/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'hemo_concentration'
